# %% [markdown]
# <a href="https://colab.research.google.com/github/SongJaeIk/aiclass/blob/main/AI_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel('data.xlsx', header=None)
df
# Out:
#     0   1   2
# 0  10  20  30
# 1  40  50  60

# %%
import pandas as pd
df = pd.read_csv('student.csv')
df
# Out:
#    height  weight
# 0    1.70      65
# 1    1.60      52
# 2    1.75      70
# 3    1.80      80

# %%
df.height
# Out:
# 0    1.70
# 1    1.60
# 2    1.75
# 3    1.80
# Name: height, dtype: float64

# %%
print(df.weight)
print(df.height)
# Out:
# 0    65
# 1    52
# 2    70
# 3    80
# Name: weight, dtype: int64
# 0    1.70
# 1    1.60
# 2    1.75
# 3    1.80
# Name: height, dtype: float64

# %%
df=pd.read_csv('Student_Marks.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  100 non-null    int64
#  1   time_study      100 non-null    float64
#  2   Marks           100 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
print("결측치(비어있음)가 있다면, sol1) 채워넣기 or sol2) 제거하기")
print("채워넣을 때는 데이터를 분석해 평균값을 넣던지, 아니면 최하값을 넣던지 등등.. 미리 판단 해야 함.")
print("제거는 그냥 하면 됨 ㅇㅇ;")
# Out:
# 결측치(비어있음)가 있다면, sol1) 채워넣기 or sol2) 제거하기
# 채워넣을 때는 데이터를 분석해 평균값을 넣던지, 아니면 최하값을 넣던지 등등.. 미리 판단 해야 함.
# 제거는 그냥 하면 됨 ㅇㅇ;

# %%
df.describe()
# Out:
#        number_courses  time_study       Marks
# count      100.000000  100.000000  100.000000
# mean         5.290000    4.077140   24.417690
# std          1.799523    2.372914   14.326199
# min          3.000000    0.096000    5.609000
# 25%          4.000000    2.058500   12.633000
# 50%          5.000000    4.022000   20.059500
# 75%          7.000000    6.179250   36.676250
# max          8.000000    7.957000   55.299000

# %%
df.isnull()
# Out:
#     number_courses  time_study  Marks
# 0            False       False  False
# 1            False       False  False
# 2            False       False  False
# 3            False       False  False
# 4            False       False  False
# ..             ...         ...    ...
# 95           False       False  False
# 96           False       False  False
# 97           False       False  False
# 98           False       False  False
# 99           False       False  False
#
# [100 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# number_courses    0
# time_study        0
# Marks             0
# dtype: int64
